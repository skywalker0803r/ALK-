# %%
#!pip install --upgrade xlrd
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/ALK硫酸腐蝕預測/操作條件.xls',sheet_name='資料擷取')
df
# Out:
#       Unnamed: 0    Unnamed: 1   Unnamed: 2   Unnamed: 3    Unnamed: 4  \
# 0            NaN    C-6301塔頂壓力   C-6301塔頂溫度   C-6301塔底溫度    C-6301塔頂回流
# 1           TIME  63PC001.MEAS  63TI043.PNT  63TI040.PNT  63FC004.MEAS
# 2     2010/01/01           6.1         57.3         66.3            60
# 3     2010/01/02           6.1         57.2         66.3            60
# 4     2010/01/03           6.1         57.1         66.4            60
# ...          ...           ...          ...          ...           ...
# 4337  2021/11/14             5         47.2         61.1            25
# 4338  2021/11/15             5         47.1           61            25
# 4339  2021/11/16             5         47.1         60.9            25
# 4340  2021/11/17             5           47         60.9            25
# 4341  2021/11/18             5           47         60.9            25
#
#         Unnamed: 5    Unnamed: 6         C-6301塔頂組成            Unnamed: 8  \
# 0     C-6301塔頂產品流量  C-6301塔底產品流量                NaN                   NaN
# 1     63FC003.MEAS   63FI101.PNT  S6301D-M_C2C4E-M%  S6301D-M_N_BUTANE-M%
# 2              108          22.7            10.3961               8.21355
# 3              108          22.8            11.1381               8.57479
# 4              108          22.2            10.2551               8.32087
# ...            ...           ...                ...                   ...
# 4337           112           3.3            11.6894               10.3815
# 4338           112           3.6            11.6968               10.4777
# 4339         112.9           3.7            11.4967               10.5913
# 4340         113.9             4            11.5928               10.7457
# 4341           114             4            11.3458                10.648
#
#             Unnamed: 9  ...       Unnamed: 112       Unnamed: 113  \
# 0                  NaN  ...  V-6311→B-6301入口壓力  V-6311→B-6301入口溫度
# 1     S6301D-M_I_C4-M%  ...        63PI056.PNT       63TI097A.PNT
# 2              39.4413  ...                0.1                  4
# 3              37.8781  ...                0.1                  4
# 4              40.6469  ...                0.1                3.9
# ...                ...  ...                ...                ...
# 4337           41.1423  ...                0.1                7.2
# 4338            41.255  ...                0.1                7.3
# 4339           41.7672  ...                0.1                7.2
# 4340           41.3603  ...                0.1                6.9
# 4341           42.1592  ...                0.1                6.8
#
#            Unnamed: 114  Unnamed: 115  Unnamed: 116  Unnamed: 117  \
# 0     V-6312→B-6301入口溫度    B-6301出口溫度    B-6301出口流量    B-6301出口壓力
# 1          63TI300A.PNT  63TI004A.PNT  63FI013W.PNT  63PC008.MEAS
# 2                  12.6          62.4         164.2           4.7
# 3                  12.8          62.6         162.6           4.7
# 4                  12.7          62.6         160.6           4.7
# ...                 ...           ...           ...           ...
# 4337               15.9          65.8         153.5           4.9
# 4338                 16          65.9         153.1           4.9
# 4339               16.4          65.7         154.4           4.9
# 4340               16.7          65.4         155.5           4.9
# 4341               16.5          65.4         154.8           4.9
#
#           Unnamed: 118      Unnamed: 119      Unnamed: 120  \
# 0     V-6313回流V-6312流量  V-6312補充R-6301流量  V-6312補充R-6302流量
# 1        63FC017A.MEAS      63FC015.MEAS      63FC016.MEAS
# 2                  NaN             110.5             110.5
# 3                  NaN             109.3             109.3
# 4                  NaN             108.4             108.4
# ...                ...               ...               ...
# 4337             279.4             119.5             110.3
# 4338               278             117.9             108.8
# 4339               281             117.9             108.8
# 4340             283.9             118.6             109.5
# 4341             280.1             118.8             109.7
#
#                     S-6325
# 0                     硫酸濃度
# 1     S6325D-TOTALACID-WT%
# 2                    91.15
# 3                     91.6
# 4                    91.19
# ...                    ...
# 4337                  92.6
# 4338                 92.37
# 4339                 92.55
# 4340                  92.5
# 4341                 92.39
#
# [4342 rows x 122 columns]

# %%
c = df.iloc[1,1:].values
v = df.iloc[2:,1:].values
d = pd.DataFrame(v,columns=c)
d = d.dropna(axis=1,how='all')
d = d.dropna(axis=0,how='all')
d = d.fillna(method='ffill')
d = d.fillna(method='bfill')
d
# Out:
#       63PC001.MEAS  63TI043.PNT  63TI040.PNT  63FC004.MEAS  63FC003.MEAS  \
# 0              6.1         57.3         66.3          60.0         108.0
# 1              6.1         57.2         66.3          60.0         108.0
# 2              6.1         57.1         66.4          60.0         108.0
# 3              6.1         57.0         66.4          60.0         108.0
# 4              6.1         56.9         66.5          60.0         109.8
# ...            ...          ...          ...           ...           ...
# 4335           5.0         47.2         61.1          25.0         112.0
# 4336           5.0         47.1         61.0          25.0         112.0
# 4337           5.0         47.1         60.9          25.0         112.9
# 4338           5.0         47.0         60.9          25.0         113.9
# 4339           5.0         47.0         60.9          25.0         114.0
#
#       63FI101.PNT  S6301D-M_C2C4E-M%  S6301D-M_N_BUTANE-M%  S6301D-M_I_C4-M%  \
# 0            22.7           10.39610               8.21355           39.4413
# 1            22.8           11.13810               8.57479           37.8781
# 2            22.2           10.25510               8.32087           40.6469
# 3            22.1           10.68940               8.60413           39.1715
# 4            22.1            9.58062               8.11639           43.4791
# ...           ...                ...                   ...               ...
# 4335          3.3           11.68940              10.38150           41.1423
# 4336          3.6           11.69680              10.47770           41.2550
# 4337          3.7           11.49670              10.59130           41.7672
# 4338          4.0           11.59280              10.74570           41.3603
# 4339          4.0           11.34580              10.64800           42.1592
#
#       S6301D-M_I_BUTENE-M%  ...  63PI056.PNT  63TI097A.PNT  63TI300A.PNT  \
# 0                 7.801000  ...          0.1           4.0          12.6
# 1                 7.953000  ...          0.1           4.0          12.8
# 2                 7.765000  ...          0.1           3.9          12.7
# 3                 7.904000  ...          0.1           4.0          12.8
# 4                 7.517000  ...          0.1           3.8          12.7
# ...                    ...  ...          ...           ...           ...
# 4335              0.463594  ...          0.1           7.2          15.9
# 4336              0.672790  ...          0.1           7.3          16.0
# 4337              0.510040  ...          0.1           7.2          16.4
# 4338              0.652470  ...          0.1           6.9          16.7
# 4339              0.530990  ...          0.1           6.8          16.5
#
#       63TI004A.PNT  63FI013W.PNT  63PC008.MEAS  63FC017A.MEAS  63FC015.MEAS  \
# 0             62.4         164.2           4.7          231.4         110.5
# 1             62.6         162.6           4.7          231.4         109.3
# 2             62.6         160.6           4.7          231.4         108.4
# 3             62.8         159.5           4.7          231.4         108.2
# 4             62.7         158.1           4.7          231.4         107.0
# ...            ...           ...           ...            ...           ...
# 4335          65.8         153.5           4.9          279.4         119.5
# 4336          65.9         153.1           4.9          278.0         117.9
# 4337          65.7         154.4           4.9          281.0         117.9
# 4338          65.4         155.5           4.9          283.9         118.6
# 4339          65.4         154.8           4.9          280.1         118.8
#
#       63FC016.MEAS  S6325D-TOTALACID-WT%
# 0            110.5                 91.15
# 1            109.3                 91.60
# 2            108.4                 91.19
# 3            108.2                 91.14
# 4            107.0                 91.48
# ...            ...                   ...
# 4335         110.3                 92.60
# 4336         108.8                 92.37
# 4337         108.8                 92.55
# 4338         109.5                 92.50
# 4339         109.7                 92.39
#
# [4340 rows x 116 columns]

# %%
import requests
url = 'https://gist.githubusercontent.com/skywalker0803r/98384fe734d607b39438f3e2192c8276/raw/47a4aed4e8b62ec217c183c1c9891fa5e6f73dc9/feature_select_armory.py'
exec(requests.get(url).text)

# %%
x_col = d.columns[:-1].values.tolist()
y_col = d.columns[-1]
result,lasso_model = lasso_find_coef(d,x_col,y_col)

# %%
print('LASSO係數')
result.abs().T.sort_values(by='coef',ascending=False).head(10)
# Out:
# LASSO係數
#                        coef
# 63TI004A.PNT       0.036053
# 63TI043.PNT        0.020762
# S6324D-L_C2C4E-M%  0.018581
# 63LI028S.PNT       0.013636
# 63LI026S.PNT       0.010363
# 63LI017.PNT        0.010316
# 63FI013W.PNT       0.008733
# 63FC017A.MEAS      0.002945
# 63LI015S.PNT       0.002220
# 63II018A.PNT       0.000000

# %%
key_features = result.abs().T.sort_values(by='coef',ascending=False).head(10).index.tolist()
print('皮爾森係數')
d[key_features+[y_col]].corr().abs()[['S6325D-TOTALACID-WT%']].sort_values(by='S6325D-TOTALACID-WT%',ascending=False).iloc[1:]
# Out:
# 皮爾森係數
#                    S6325D-TOTALACID-WT%
# 63LI026S.PNT                   0.280534
# S6324D-L_C2C4E-M%              0.264634
# 63LI028S.PNT                   0.214670
# 63TI043.PNT                    0.202341
# 63TI004A.PNT                   0.180295
# 63FC017A.MEAS                  0.156893
# 63LI017.PNT                    0.128034
# 63FI013W.PNT                   0.113975
# 63II018A.PNT                   0.106459
# 63LI015S.PNT                   0.058751

# %%
y_pred = lasso_model.predict(d[x_col])
y_real = d[y_col].values
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
def mape(actual, pred): 
  actual, pred = np.array(actual), np.array(pred)
  return np.mean(np.abs((actual - pred) / actual)) * 100
print('LASSO建模結果')
print('R2:',r2_score(y_real,y_pred))
print('RMSE:',np.sqrt(mean_squared_error(y_real,y_pred)))
print('MAPE:',mape(y_real,y_pred))
# Out:
# LASSO建模結果
# R2: 0.36008917757216363
# RMSE: 1.0730229254641104
# MAPE: 0.8888353587588034
